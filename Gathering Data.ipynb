# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
df = pd.read_csv('Data/new-delhi us embassy, india-air-quality.csv')
df.sample(5)
# Out:
#             date   pm25
# 2093   2015/6/19    163
# 366    2020/5/14    124
# 1588   2016/7/20     95
# 188   2020/11/22    203
# 899   2018/12/12    255

# %%
df['DATE'] = pd.to_datetime(df['date'])
df.DATE
# Out:
# 0      2021-05-01
# 1      2021-05-02
# 2      2021-05-03
# 3      2021-05-04
# 4      2021-05-05
#           ...
# 2208   2014-12-24
# 2209   2014-12-25
# 2210   2014-12-26
# 2211   2014-12-27
# 2212   2014-12-28
# Name: DATE, Length: 2213, dtype: datetime64[ns]

# %%
df['DATE'] = df['DATE'].apply(lambda x: fun(x,df))

def fun(x,df):
    print(x.year)
# Out:
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# ...

# %%
os.getcwd()
year = "2010"
path = "/home/toseef/Desktop/AQIProject/Data/Scrapped_Data/"+year
os.chdir(path)
os.getcwd()
# Out:
# '/home/toseef/Desktop/AQIProject/Data/Scrapped_Data/2010'
